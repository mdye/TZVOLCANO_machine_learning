# %%
# import requests

import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
from zlib import crc32


from sklearn.linear_model import LinearRegression

# %%
# r = requests.get(url)
# print(r.status_code)
# print(r.text)

INSTRUMENT_ID = '1'
START = "2021-02-01T00:00"
END = "2021-02-01T12:00"

# %%
def load_olo_data(instrument_id, start, end):
    instrument_id = '1'
    start = "2021-02-01T00:00"
    end = "2021-02-01T12:00"
    # url = "http://tzvolcano.chordsrt.com/api/v1/data/4.csv?start=2021-02-01T00:00&end=2021-02-02T00:00"
    # url = "http://tzvolcano.chordsrt.com/api/v1/data/4.csv?start=2021-02-01T00:00&end=2021-02-02T00:00"
    url = f'http://tzvolcano.chordsrt.com/api/v1/data/{instrument_id}.csv?start={start}&end={end}'
    print(url)

#     return pd.read_csv(url,
#                     parse_dates=['Time'],
#                     header=18
#                     )
    
# df = pandas.read_csv('hrdata.csv')
# df = pd.read_csv(r.text)
# df = pd.read_csv(url)
    return pd.read_csv(url,
#                     index_col='Time', 
                    parse_dates=['Time'],
                    header=18
                    )


# original_data.info()
# original_data.describe()
# original_data.head()

# %%
original_data = load_olo_data(INSTRUMENT_ID, START, END)
# Out:
# http://tzvolcano.chordsrt.com/api/v1/data/1.csv?start=2021-02-01T00:00&end=2021-02-01T12:00

# %%
original_data["seconds_since_epoch"] = original_data['Time'].astype(np.int64)

original_data.keys()
# Out:
# Index(['Time', 'Latitude', 'Longitude', 'Height', 'seconds_since_epoch'], dtype='object')

# %%
original_data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
original_data.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
# df.plot(y="Height", figsize=(20,15))
original_data.plot(x="Time", y="Height")
original_data.plot(x="Time", y="Longitude")
original_data.plot(x="Time", y="Latitude")
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
original_data.corr()
# Out:
#                      Latitude  Longitude    Height  seconds_since_epoch
# Latitude             1.000000  -0.379469 -0.069864             0.304082
# Longitude           -0.379469   1.000000 -0.292309            -0.027832
# Height              -0.069864  -0.292309  1.000000            -0.225364
# seconds_since_epoch  0.304082  -0.027832 -0.225364             1.000000

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25154 entries, 0 to 25153
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Time                 25154 non-null  datetime64[ns, UTC]
#  1   Latitude             25154 non-null  float64
#  2   Longitude            25154 non-null  float64
#  3   Height               25154 non-null  float64
#  4   seconds_since_epoch  25154 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(3), int64(1)
# memory usage: 982.7 KB

# %%
# def test_set_check(identifier, test_ratio):
#     return crc32(np.int64(identifier)) & 0xffffffff < test_ratio *2**32

# %%
# def split_train_test_by_id(data, test_ratio, id_column):
#     ids = data[id_column]
#     in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio))
#     return data.loc[~in_test_set], data.loc[in_test_set]

# %%
original_data.keys()
# Out:
# Index(['Time', 'Latitude', 'Longitude', 'Height', 'seconds_since_epoch'], dtype='object')

# %%
# from uuid import uuid4
# int(uuid4())
# import sys
# sys.maxsize

# import random

# original_data["id"] = random.randint(0, sys.maxsize)

# %%
# split_train_test_by_id(original_data, 0.2, "id")

# %%
def split_train_test(data, test_ratio):
    #     Seed ramdom generator so the same indices are retrieved every time
    np.random.seed(42)
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

train_data, test_data = split_train_test(original_data, 0.2)

print(len(original_data))
print(len(train_data))
print(len(test_data))
# Out:
# 25154
# 20124
# 5030

# %%
train_data.keys()
# Out:
# Index(['Time', 'Latitude', 'Longitude', 'Height', 'seconds_since_epoch'], dtype='object')

# %%
numerical_data = original_data.drop(["Time"], axis=1)

# %%
numerical_data.keys()
# Out:
# Index(['Latitude', 'Longitude', 'Height', 'seconds_since_epoch'], dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler()),
])


original_transformed = num_pipeline.fit_transform(numerical_data)

# %%
from sklearn.compose import ColumnTransformer

num_attributes = list(numerical_data)

full_pipeline = ColumnTransformer([
    ("num", num_pipeline, num_attributes)
])

training_prepared = full_pipeline.fit_transform(numerical_data)

# %%
lin_reg = LinearRegression()
lin_reg.fit(training_prepared,training_prepared)
# Out:
# LinearRegression()
